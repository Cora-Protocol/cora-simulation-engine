# %%
from example.monte_carlo_simulation_setup import find_ltv_for_var

# %%
max_ltv = find_ltv_for_var(
    asset = "ETH",
    monthly_var_ratio_limit = 0.01,
    fee_model="bsmtradsum",
)

print(f"Max LTV: {max_ltv:.2%}")
# Out:
# Max LTV: 70.00%
